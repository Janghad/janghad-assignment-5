# %%
import numpy as np
import pandas as pd

# %%
class KNN:
    def __init__(self, k=3, distance_metric='euclidean', batch_size=100):
        self.k = k
        self.distance_metric = distance_metric
        self.batch_size = batch_size

    def fit(self, X, y):
        print(f"Training KNN with k={self.k} on training data...")
        self.X_train = X
        self.y_train = y
        print(f"Training completed.")

    def predict(self, X):
        print(f"Making predictions for {len(X)} test points...")
        predictions = []
        num_test = X.shape[0]

        # Batch processing to handle large datasets
        for i in range(0, num_test, self.batch_size):
            # Get a batch of test points
            X_batch = X[i:i + self.batch_size]
            # Compute distances for the batch using vectorized computation
            distances = self.compute_distance(X_batch)

            # For each test point in the batch, find k nearest neighbors and predict
            for dist in distances:
                k_indices = np.argsort(dist)[:self.k]  # Indices of the k nearest neighbors
                k_nearest_labels = self.y_train[k_indices].astype(int)  # Convert to int
                majority_vote = np.argmax(np.bincount(k_nearest_labels))
                predictions.append(majority_vote)

        print(f"Predictions completed.")
        return predictions

    def compute_distance(self, X_test):
        # Compute Euclidean distance for all test points at once (vectorized)
        if self.distance_metric == 'euclidean':
            distances = np.sqrt(np.sum((self.X_train - X_test[:, np.newaxis]) ** 2, axis=2))
            return distances
        else:
            raise ValueError("Unsupported distance metric")

# %%
def preprocess_data(train_path, test_path):
    print("Loading and preprocessing data...")
    train_data = pd.read_csv(train_path)
    test_data = pd.read_csv(test_path)

    # Drop unnecessary columns
    train_data = train_data.drop(['CustomerId', 'Surname'], axis=1)
    test_data = test_data.drop(['CustomerId', 'Surname'], axis=1)

    # Encode categorical variables
    train_data['Geography'] = train_data['Geography'].astype('category').cat.codes
    train_data['Gender'] = train_data['Gender'].astype('category').cat.codes
    test_data['Geography'] = test_data['Geography'].astype('category').cat.codes
    test_data['Gender'] = test_data['Gender'].astype('category').cat.codes

    # Separate features and target
    X_train = train_data.drop('Exited', axis=1).values
    y_train = train_data['Exited'].values
    X_test = test_data.values

    # Manual standardization of the features
    mean = np.mean(X_train, axis=0)
    std = np.std(X_train, axis=0)

    # Standardize the training and test data
    X_train = (X_train - mean) / std
    X_test = (X_test - mean) / std

    print("Data preprocessing completed.")
    return X_train, y_train, X_test

# %%
def cross_validate(X, y, knn, n_splits=5):
    print("Starting cross-validation...")
    n = len(X)
    fold_size = n // n_splits
    indices = np.arange(n)
    np.random.shuffle(indices)

    accuracy_scores = []

    for fold in range(n_splits):
        print(f"Processing fold {fold + 1} of {n_splits}...")
        val_start = fold * fold_size
        val_end = val_start + fold_size if fold != n_splits - 1 else n
        val_indices = indices[val_start:val_end]
        train_indices = np.concatenate([indices[:val_start], indices[val_end:]])

        X_train, y_train = X[train_indices], y[train_indices]
        X_val, y_val = X[val_indices], y[val_indices]

        knn.fit(X_train, y_train)
        y_pred = knn.predict(X_val)

        accuracy = np.mean(y_pred == y_val)
        accuracy_scores.append(accuracy)

        print(f"Fold {fold + 1} accuracy: {accuracy:.4f}")

    print("Cross-validation completed.")
    return np.mean(accuracy_scores)

# %%
print("Loading data...")
X, y, X_test = preprocess_data('/content/train.csv', '/content/test.csv')

# Create and evaluate model
knn = KNN(k=5, distance_metric='euclidean')

# Perform cross-validation
print("Starting cross-validation with k=5...")
cv_scores = cross_validate(X, y, knn)
print("Cross-validation scores:", cv_scores)

# Hyperparameter tuning
print("Starting hyperparameter tuning...")
best_k = 5
best_score = 0
for k in range(1, 20):
    print(f"Evaluating k={k}...")
    knn = KNN(k=k, distance_metric='euclidean')
    cv_score = cross_validate(X, y, knn)
    print(f"k = {k}, Cross-validation accuracy = {cv_score:.4f}")

    if cv_score > best_score:
        best_score = cv_score
        best_k = k

print(f"Best k found: {best_k} with cross-validation accuracy: {best_score:.4f}")

# Train on full dataset with optimal hyperparameters and make predictions on test set
print(f"Training final model with k={best_k} on full dataset...")
knn = KNN(k=best_k, distance_metric='euclidean')
knn.fit(X, y)
test_predictions = knn.predict(X_test)

# Save test predictions
print("Saving predictions to submissions.csv...")
pd.DataFrame({'id': pd.read_csv('/content/test.csv')['id'], 'Exited': test_predictions}).to_csv('submissions.csv', index=False)
print("Predictions saved successfully.")
# Out:
# Loading data...
# Loading and preprocessing data...
# Data preprocessing completed.
# Starting cross-validation with k=5...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8787
# Processing fold 2 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8673
# Processing fold 3 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8687
# Processing fold 4 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8640
# Processing fold 5 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8710
# Cross-validation completed.
# Cross-validation scores: 0.8699333333333332
# Starting hyperparameter tuning...
# Evaluating k=1...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=1 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8373
# Processing fold 2 of 5...
# Training KNN with k=1 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8470
# Processing fold 3 of 5...
# Training KNN with k=1 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8483
# Processing fold 4 of 5...
# Training KNN with k=1 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8423
# Processing fold 5 of 5...
# Training KNN with k=1 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8413
# Cross-validation completed.
# k = 1, Cross-validation accuracy = 0.8433
# Evaluating k=2...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=2 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8573
# Processing fold 2 of 5...
# Training KNN with k=2 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8620
# Processing fold 3 of 5...
# Training KNN with k=2 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8690
# Processing fold 4 of 5...
# Training KNN with k=2 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8500
# Processing fold 5 of 5...
# Training KNN with k=2 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8587
# Cross-validation completed.
# k = 2, Cross-validation accuracy = 0.8594
# Evaluating k=3...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=3 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8690
# Processing fold 2 of 5...
# Training KNN with k=3 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8557
# Processing fold 3 of 5...
# Training KNN with k=3 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8627
# Processing fold 4 of 5...
# Training KNN with k=3 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8640
# Processing fold 5 of 5...
# Training KNN with k=3 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8700
# Cross-validation completed.
# k = 3, Cross-validation accuracy = 0.8643
# Evaluating k=4...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=4 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8717
# Processing fold 2 of 5...
# Training KNN with k=4 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8553
# Processing fold 3 of 5...
# Training KNN with k=4 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8560
# Processing fold 4 of 5...
# Training KNN with k=4 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8607
# Processing fold 5 of 5...
# Training KNN with k=4 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8743
# Cross-validation completed.
# k = 4, Cross-validation accuracy = 0.8636
# Evaluating k=5...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8737
# Processing fold 2 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8707
# Processing fold 3 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8697
# Processing fold 4 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8667
# Processing fold 5 of 5...
# Training KNN with k=5 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8747
# Cross-validation completed.
# k = 5, Cross-validation accuracy = 0.8711
# Evaluating k=6...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=6 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8690
# Processing fold 2 of 5...
# Training KNN with k=6 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8707
# Processing fold 3 of 5...
# Training KNN with k=6 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8693
# Processing fold 4 of 5...
# Training KNN with k=6 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8757
# Processing fold 5 of 5...
# Training KNN with k=6 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8560
# Cross-validation completed.
# k = 6, Cross-validation accuracy = 0.8681
# Evaluating k=7...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=7 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8703
# Processing fold 2 of 5...
# Training KNN with k=7 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8737
# Processing fold 3 of 5...
# Training KNN with k=7 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8707
# Processing fold 4 of 5...
# Training KNN with k=7 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8703
# Processing fold 5 of 5...
# Training KNN with k=7 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8673
# Cross-validation completed.
# k = 7, Cross-validation accuracy = 0.8705
# Evaluating k=8...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=8 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8703
# Processing fold 2 of 5...
# Training KNN with k=8 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8750
# Processing fold 3 of 5...
# Training KNN with k=8 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8680
# Processing fold 4 of 5...
# Training KNN with k=8 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8687
# Processing fold 5 of 5...
# Training KNN with k=8 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8783
# Cross-validation completed.
# k = 8, Cross-validation accuracy = 0.8721
# Evaluating k=9...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=9 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8720
# Processing fold 2 of 5...
# Training KNN with k=9 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8690
# Processing fold 3 of 5...
# Training KNN with k=9 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8660
# Processing fold 4 of 5...
# Training KNN with k=9 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8840
# Processing fold 5 of 5...
# Training KNN with k=9 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8757
# Cross-validation completed.
# k = 9, Cross-validation accuracy = 0.8733
# Evaluating k=10...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=10 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8760
# Processing fold 2 of 5...
# Training KNN with k=10 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8823
# Processing fold 3 of 5...
# Training KNN with k=10 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8620
# Processing fold 4 of 5...
# Training KNN with k=10 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8643
# Processing fold 5 of 5...
# Training KNN with k=10 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8663
# Cross-validation completed.
# k = 10, Cross-validation accuracy = 0.8702
# Evaluating k=11...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=11 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8787
# Processing fold 2 of 5...
# Training KNN with k=11 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8660
# Processing fold 3 of 5...
# Training KNN with k=11 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8670
# Processing fold 4 of 5...
# Training KNN with k=11 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8753
# Processing fold 5 of 5...
# Training KNN with k=11 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8727
# Cross-validation completed.
# k = 11, Cross-validation accuracy = 0.8719
# Evaluating k=12...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=12 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8653
# Processing fold 2 of 5...
# Training KNN with k=12 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8753
# Processing fold 3 of 5...
# Training KNN with k=12 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8763
# Processing fold 4 of 5...
# Training KNN with k=12 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8823
# Processing fold 5 of 5...
# Training KNN with k=12 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8667
# Cross-validation completed.
# k = 12, Cross-validation accuracy = 0.8732
# Evaluating k=13...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=13 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8777
# Processing fold 2 of 5...
# Training KNN with k=13 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8833
# Processing fold 3 of 5...
# Training KNN with k=13 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8637
# Processing fold 4 of 5...
# Training KNN with k=13 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8717
# Processing fold 5 of 5...
# Training KNN with k=13 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8740
# Cross-validation completed.
# k = 13, Cross-validation accuracy = 0.8741
# Evaluating k=14...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=14 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8723
# Processing fold 2 of 5...
# Training KNN with k=14 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8723
# Processing fold 3 of 5...
# Training KNN with k=14 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8747
# Processing fold 4 of 5...
# Training KNN with k=14 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8723
# Processing fold 5 of 5...
# Training KNN with k=14 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8710
# Cross-validation completed.
# k = 14, Cross-validation accuracy = 0.8725
# Evaluating k=15...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=15 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8657
# Processing fold 2 of 5...
# Training KNN with k=15 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8773
# Processing fold 3 of 5...
# Training KNN with k=15 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8683
# Processing fold 4 of 5...
# Training KNN with k=15 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8727
# Processing fold 5 of 5...
# Training KNN with k=15 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8717
# Cross-validation completed.
# k = 15, Cross-validation accuracy = 0.8711
# Evaluating k=16...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=16 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8770
# Processing fold 2 of 5...
# Training KNN with k=16 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8683
# Processing fold 3 of 5...
# Training KNN with k=16 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8730
# Processing fold 4 of 5...
# Training KNN with k=16 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8760
# Processing fold 5 of 5...
# Training KNN with k=16 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8607
# Cross-validation completed.
# k = 16, Cross-validation accuracy = 0.8710
# Evaluating k=17...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=17 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8787
# Processing fold 2 of 5...
# Training KNN with k=17 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8750
# Processing fold 3 of 5...
# Training KNN with k=17 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8657
# Processing fold 4 of 5...
# Training KNN with k=17 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8850
# Processing fold 5 of 5...
# Training KNN with k=17 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8667
# Cross-validation completed.
# k = 17, Cross-validation accuracy = 0.8742
# Evaluating k=18...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=18 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8853
# Processing fold 2 of 5...
# Training KNN with k=18 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8607
# Processing fold 3 of 5...
# Training KNN with k=18 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8867
# Processing fold 4 of 5...
# Training KNN with k=18 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8720
# Processing fold 5 of 5...
# Training KNN with k=18 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8640
# Cross-validation completed.
# k = 18, Cross-validation accuracy = 0.8737
# Evaluating k=19...
# Starting cross-validation...
# Processing fold 1 of 5...
# Training KNN with k=19 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 1 accuracy: 0.8687
# Processing fold 2 of 5...
# Training KNN with k=19 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 2 accuracy: 0.8790
# Processing fold 3 of 5...
# Training KNN with k=19 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 3 accuracy: 0.8633
# Processing fold 4 of 5...
# Training KNN with k=19 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 4 accuracy: 0.8703
# Processing fold 5 of 5...
# Training KNN with k=19 on training data...
# Training completed.
# Making predictions for 3000 test points...
# Predictions completed.
# Fold 5 accuracy: 0.8847
# Cross-validation completed.
# k = 19, Cross-validation accuracy = 0.8732
# Best k found: 17 with cross-validation accuracy: 0.8742
# Training final model with k=17 on full dataset...
# Training KNN with k=17 on training data...
# Training completed.
# Making predictions for 10000 test points...
# Predictions completed.
# Saving predictions to submissions.csv...
# Predictions saved successfully.
